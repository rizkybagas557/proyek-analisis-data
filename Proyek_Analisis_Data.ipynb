# %% [markdown]
# # Proyek Analisis Data: [Air Quality Dataset]
# - **Nama:** [Rizky Bagas Kurniawan]
# - **Email terdaftar :** [rizkybagas557@gmail.com]
# - **Email Coding Camp :** [mc200d5y1106@student.devacademy.id]
# - **ID Dicoding:** [MC200D5Y1106]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana korelasi antara berbagai polutan (PM2.5, PM10, SO2, NO2, CO, O3)?
# - Apakah ada hubungan antara kecepatan angin (WSPM) dan tingkat polusi udara?
# - Bagaimana kualitas udara pada masing masing stasiun?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
Aotizhongxin_df = pd.read_csv("E:\OneDrive - Universitas Diponegoro\Programming Code\Proyek\proyek analisis data\Data\PRSA_Data_Aotizhongxin_20130301-20170228.csv")
Aotizhongxin_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %% [markdown]
# **Insight:**
# - menampilkan 5 baris pertama dari DataFrame `Aotizhongxin_df`.

# %%
Changping_df = pd.read_csv("E:\OneDrive - Universitas Diponegoro\Programming Code\Proyek\proyek analisis data\Data\PRSA_Data_Changping_20130301-20170228.csv")
Changping_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %% [markdown]
# **Insight:**
# - Menampilkan 5 baris pertama dari DataFrame `Changping_df`.

# %%
Dingling_df = pd.read_csv("E:\OneDrive - Universitas Diponegoro\Programming Code\Proyek\proyek analisis data\Data\PRSA_Data_Dingling_20130301-20170228.csv")
Dingling_df.head()
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %% [markdown]
# **Insight:**
# - Menampilkan 5 baris pertama dari dataframe `Dingling_df`.

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai tabel `Aotizhongxing_df`.

# %%
Aotizhongxin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Aotizhongxin_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       925
# PM10        718
# SO2         935
# NO2        1023
# CO         1776
# O3         1719
# TEMP         20
# PRES         20
# DEWP         20
# RAIN         20
# wd           81
# WSPM         14
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi data Aotizhongxin: ", Aotizhongxin_df.duplicated().sum())
# Out:
# Jumlah duplikasi data Aotizhongxin:  0

# %%
Aotizhongxin_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34139.000000  34346.000000  34129.000000  34041.000000  33288.000000
# mean      82.773611    110.060391     17.375901     59.305833   1262.945145
# ...

# %% [markdown]
# **Insight:**
# - Ada perbedaan jumlah data pada kolom nomor 5-16.
# - Tidak ada duplikasi data.
# - Memeriksa parameter statistik.

# %% [markdown]
# #### Menilai tabel `Changping_df`.

# %%
Changping_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Changping_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       774
# PM10        582
# SO2         628
# NO2         667
# CO         1521
# O3          604
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Changping_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Changping_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34290.000000  34482.000000  34436.000000  34397.000000  33543.000000
# mean      71.099743     94.657871     14.958906     44.182086   1152.301345
# ...

# %% [markdown]
# **Insight:**
# - Ada perbedaan jumlah data pada kolom nomor 5-16.
# - Tidak ada duplikasi data.
# - Memeriksa parameter statistik.

# %% [markdown]
# #### Memulai tabel `Dingling_df`.

# %%
Dingling_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
Dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", Dingling_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
Dingling_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34285.000000  34408.000000  34334.000000  33830.000000  33052.000000
# mean      65.989497     83.739723     11.749650     27.585467    904.896073
# ...

# %% [markdown]
# **Insight:**
# - Ada perbedaan jumlah data pada kolom nomor 5-16.
# - Tidak ada duplikasi data.
# - Memeriksa parameter statistik.

# %% [markdown]
# ### Cleaning Data

# %%
Aotizhongxin_df.isna().sum()
Changping_df.isna().sum()
Dingling_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       779
# PM10        656
# SO2         730
# NO2        1234
# CO         2012
# O3         1214
# TEMP         53
# PRES         50
# DEWP         53
# RAIN         51
# wd          140
# WSPM         43
# station       0
# dtype: int64

# %%
# Interpolasi hanya pada kolom numerik
Aotizhongxin_df[Aotizhongxin_df.select_dtypes(include=['number']).columns] = \
    Aotizhongxin_df.select_dtypes(include=['number']).interpolate(method='linear', limit_direction='both')
Changping_df[Changping_df.select_dtypes(include=['number']).columns] = \
    Changping_df.select_dtypes(include=['number']).interpolate(method='linear', limit_direction='both')
Dingling_df[Dingling_df.select_dtypes(include=['number']).columns] = \
    Dingling_df.select_dtypes(include=['number']).interpolate(method='linear', limit_direction='both')

# %%
Aotizhongxin_df.isna().sum()
Changping_df.isna().sum()
Dingling_df.isna().sum()
# Out:
# No           0
# year         0
# month        0
# day          0
# hour         0
# PM2.5        0
# PM10         0
# SO2          0
# NO2          0
# CO           0
# O3           0
# TEMP         0
# PRES         0
# DEWP         0
# RAIN         0
# wd         140
# WSPM         0
# station      0
# dtype: int64

# %%
Aotizhongxin_df.wd.value_counts()
# Out:
# wd
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: count, dtype: int64

# %%
Aotizhongxin_df.fillna(value="NE", inplace=True)
Aotizhongxin_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
Changping_df.wd.value_counts()
# Out:
# wd
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64

# %%
Changping_df.fillna(value="NNW", inplace=True)
Changping_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
Dingling_df.wd.value_counts()
# Out:
# wd
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64

# %%
Dingling_df.fillna(value="NNW", inplace=True)
Dingling_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %% [markdown]
# **Insight:**
# - Data bertipe integer dan float diselesaikan dengan cara interpolate karena berjalan seiring waktu
# - Data bertipe object diselesaikan dengan mengganti data dengan data yang sering muncul

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
Aotizhongxin_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
Changping_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %%
Dingling_df.describe(include="all")
# Out:
#                   No          year         month           day          hour  \
# count   35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean    17532.500000   2014.662560      6.522930     15.729637     11.500000
# std     10122.249256      1.177213      3.448752      8.800218      6.922285
# min         1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%      8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%     17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%     26298.250000   2016.000000     10.000000     23.000000     17.250000
# max     35064.000000   2017.000000     12.000000     31.000000     23.000000
#
# ...

# %% [markdown]
# ### persebaran kualitas udara tiap stasiun tiap tahun

# %%
pivot_table = Aotizhongxin_df.pivot_table(
    values=["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"],  # Kolom yang dianalisis
    index="year",  # Baris berdasarkan tahun
    columns="station",  # Kolom berdasarkan tempat (lokasi)
    aggfunc="mean"  # Fungsi agregasi (rata-rata)
)

# Menampilkan hasil pivot table
print(pivot_table)
# Out:
#                   CO          NO2           O3         PM10        PM2.5  \
# station Aotizhongxin Aotizhongxin Aotizhongxin Aotizhongxin Aotizhongxin
# year
# 2013     1163.919458    63.355500    47.206555   112.940836    82.439202
# 2014     1186.718037    63.164053    48.594041   122.282112    89.747603
# 2015     1436.889269    60.939047    63.604132   112.176747    81.831724
# 2016     1190.215164    48.402493    61.854793    94.445811    74.236680
# 2017     1666.454802    66.229520    47.436088   106.988347    94.379237
#
#                  SO2
# station Aotizhongxin
# year
# 2013       23.599799
# 2014       21.515582
# 2015       14.354195
# 2016       10.833732
# 2017       20.827331

# %%
pivot_table = Changping_df.pivot_table(
    values=["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"],  # Kolom yang dianalisis
    index="year",  # Baris berdasarkan tahun
    columns="station",  # Kolom berdasarkan tempat (lokasi)
    aggfunc="mean"  # Fungsi agregasi (rata-rata)
)

# Menampilkan hasil pivot table
print(pivot_table)
# Out:
#                   CO        NO2         O3        PM10      PM2.5        SO2
# station    Changping  Changping  Changping   Changping  Changping  Changping
# year
# 2013     1022.978758  40.960527  61.132385   91.176675  72.393246  19.134785
# 2014     1229.971461  45.968002  63.019235  107.611416  79.881998  21.250228
# 2015     1162.431507  42.725942  58.307374   93.275696  68.832608  11.698721
# 2016     1129.764344  45.541268  54.002618   86.632115  61.665699   8.144126
# 2017     1535.769774  51.014831  33.010593   94.150777  79.802966  16.431497

# %%
pivot_table = Dingling_df.pivot_table(
    values=["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"],  # Kolom yang dianalisis
    index="year",  # Baris berdasarkan tahun
    columns="station",  # Kolom berdasarkan tempat (lokasi)
    aggfunc="mean"  # Fungsi agregasi (rata-rata)
)

# Menampilkan hasil pivot table
print(pivot_table)
# Out:
#                   CO        NO2         O3       PM10      PM2.5        SO2
# station     Dingling   Dingling   Dingling   Dingling   Dingling   Dingling
# year
# 2013      940.035607  28.768839  64.549386  78.884940  65.200980  13.955578
# 2014      890.734399  27.365046  72.762681  91.554865  75.643006  14.872983
# 2015      963.934551  26.821221  71.166486  85.374616  64.353124  11.322508
# 2016      870.810565  25.375114  75.364925  80.707707  61.701218   7.166041
# 2017     1157.062147  34.271186  53.824859  78.526483  68.281780  13.256356

# %% [markdown]
# ### Persebaran distribusi polutan berdasarkan arah angin (wd)

# %%
# Membuat pivot table berdasarkan wd (arah angin)
pivot_table = Aotizhongxin_df.pivot_table(
    values=["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"],  # Kolom yang dianalisis
    index="wd",  # Baris berdasarkan arah angin (wd)
    aggfunc="mean"  # Fungsi agregasi (rata-rata)
)

# Menampilkan hasil pivot table
print(pivot_table)
# Out:
#               CO        NO2         O3        PM10       PM2.5        SO2
# wd
# E    1760.067779  72.000420  40.205067  130.894261  108.119806  16.768817
# ENE  1761.001850  73.696957  29.699251  127.617308  104.681344  20.399930
# ESE  1626.603103  67.598678  55.309422  130.684998  106.033721  16.117609
# N     915.531921  46.111590  46.443040   85.313901   55.685653  13.322211
# NE   1510.376079  68.073291  29.900048  116.399342   93.389799  21.706828
# NNE  1139.043415  55.021736  38.403260   91.282157   68.086733  16.658796
# NNW   705.800829  34.087592  55.492462   75.045366   37.153312  11.609562
# NW    684.627852  33.885253  61.106102   67.110746   37.311411   9.741891
# S    1238.412567  57.840499  89.730535  124.861136   94.362386  20.687689
# SE   1404.490846  64.300868  69.546472  129.288496   99.666272  16.654600
# SSE  1286.266401  61.031420  83.160678  129.857670   97.932937  19.126286
# SSW  1028.832026  52.769977  97.988350  121.099181   86.435106  19.906793
# ...

# %%
# Membuat pivot table berdasarkan wd (arah angin)
pivot_table = Changping_df.pivot_table(
    values=["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"],  # Kolom yang dianalisis
    index="wd",  # Baris berdasarkan arah angin (wd)
    aggfunc="mean"  # Fungsi agregasi (rata-rata)
)

# Menampilkan hasil pivot table
print(pivot_table)
# Out:
#               CO        NO2          O3        PM10      PM2.5        SO2
# wd
# E    1329.336104  48.606425   68.197642  121.247599  93.815927  17.389578
# ENE  1335.196749  50.596168   52.846280  108.500164  84.861942  16.662407
# ESE  1310.903364  48.101486   75.915321  125.171807  98.553135  18.589210
# N    1145.164800  43.985036   44.195393   82.273425  64.354978  13.751149
# NE   1066.926937  43.836164   51.040167   83.827564  62.923049  13.716149
# NNE  1065.645175  43.287968   48.258456   78.832095  60.391767  14.109638
# NNW  1212.648229  45.009908   40.783838   87.391164  68.733820  12.899867
# NW   1062.356467  41.065202   42.793378   81.363836  57.673279  12.541784
# S    1189.528173  43.502310   93.104034  102.474164  76.156942  17.394272
# SE   1160.353029  44.766550   88.116068  116.737638  86.778141  18.495230
# SSE  1096.652783  42.355440  107.176802  113.239487  81.929282  16.709379
# SSW  1332.861477  48.248033   69.081857  103.131519  80.506488  19.797336
# ...

# %%
# Membuat pivot table berdasarkan wd (arah angin)
pivot_table = Dingling_df.pivot_table(
    values=["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"],  # Kolom yang dianalisis
    index="wd",  # Baris berdasarkan arah angin (wd)
    aggfunc="mean"  # Fungsi agregasi (rata-rata)
)

# Menampilkan hasil pivot table
print(pivot_table)
# Out:
#               CO        NO2          O3        PM10      PM2.5        SO2
# wd
# E    1102.062007  33.092896   77.854549  106.270206  89.610803  13.589560
# ENE  1088.292398  33.440554   63.327061   95.386183  78.779086  13.029427
# ESE  1156.325045  36.239154   86.603542  118.609691  97.448205  15.390299
# N     868.962976  25.334522   56.748808   70.313476  58.773533   9.915829
# NE    824.898491  25.199726   66.306400   71.727699  57.541785   9.664513
# NNE   852.900045  25.144147   59.723908   68.220140  54.580641   9.942988
# NNW   942.935107  26.440641   53.212100   77.001285  64.369952   9.593022
# NW    803.437453  22.020703   56.818167   70.712311  53.925031   9.449567
# S     955.287971  29.715966  105.675324   93.803671  73.021900  14.988952
# SE   1023.017713  34.028930   97.778907  111.568850  86.070709  16.245920
# SSE   945.476387  31.224470  118.540406  106.568000  80.693324  14.752652
# SSW  1031.580381  32.521496   80.055271   89.968073  73.434577  16.982626
# ...

# %% [markdown]
# ### Korelasi WSPM dengan polutan

# %%
correlation = Aotizhongxin_df[["WSPM", "PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]].corr()
print("Korelasi antara WSPM dan polutan:")
print(correlation["WSPM"])
# Out:
# Korelasi antara WSPM dan polutan:
# WSPM     1.000000
# PM2.5   -0.275836
# PM10    -0.179647
# SO2     -0.112397
# NO2     -0.487331
# CO      -0.275605
# O3       0.342127
# Name: WSPM, dtype: float64

# %%
correlation = Changping_df[["WSPM", "PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]].corr()
print("Korelasi antara WSPM dan polutan:")
print(correlation["WSPM"])
# Out:
# Korelasi antara WSPM dan polutan:
# WSPM     1.000000
# PM2.5   -0.270444
# PM10    -0.130415
# SO2     -0.101987
# NO2     -0.328463
# CO      -0.273787
# O3       0.231738
# Name: WSPM, dtype: float64

# %%
correlation = Dingling_df[["WSPM", "PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]].corr()
print("Korelasi antara WSPM dan polutan:")
print(correlation["WSPM"])
# Out:
# Korelasi antara WSPM dan polutan:
# WSPM     1.000000
# PM2.5   -0.254722
# PM10    -0.122692
# SO2     -0.093232
# NO2     -0.305269
# CO      -0.267643
# O3       0.244806
# Name: WSPM, dtype: float64

# %% [markdown]
# ### Korelasi antar polutan

# %%
# Menghitung matriks korelasi untuk semua polutan
correlation = Aotizhongxin_df[["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]].corr()

# Menampilkan matriks korelasi
print("Matriks Korelasi antara Polutan:")
print(correlation)
# Out:
# Matriks Korelasi antara Polutan:
#           PM2.5      PM10       SO2       NO2        CO        O3
# PM2.5  1.000000  0.875198  0.479025  0.682795  0.786052 -0.160271
# PM10   0.875198  1.000000  0.469399  0.650040  0.682026 -0.141969
# SO2    0.479025  0.469399  1.000000  0.430005  0.523269 -0.206802
# NO2    0.682795  0.650040  0.430005  1.000000  0.687243 -0.495797
# CO     0.786052  0.682026  0.523269  0.687243  1.000000 -0.320600
# O3    -0.160271 -0.141969 -0.206802 -0.495797 -0.320600  1.000000

# %%
# Menghitung matriks korelasi untuk semua polutan
correlation = Changping_df[["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]].corr()

# Menampilkan matriks korelasi
print("Matriks Korelasi antara Polutan:")
print(correlation)
# Out:
# Matriks Korelasi antara Polutan:
#           PM2.5      PM10       SO2       NO2        CO        O3
# PM2.5  1.000000  0.859519  0.462800  0.670569  0.742917 -0.104135
# PM10   0.859519  1.000000  0.426352  0.628669  0.653570 -0.052420
# SO2    0.462800  0.426352  1.000000  0.493051  0.517540 -0.190738
# NO2    0.670569  0.628669  0.493051  1.000000  0.714572 -0.469231
# CO     0.742917  0.653570  0.517540  0.714572  1.000000 -0.301951
# O3    -0.104135 -0.052420 -0.190738 -0.469231 -0.301951  1.000000

# %%
# Menghitung matriks korelasi untuk semua polutan
correlation = Dingling_df[["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]].corr()

# Menampilkan matriks korelasi
print("Matriks Korelasi antara Polutan:")
print(correlation)
# Out:
# Matriks Korelasi antara Polutan:
#           PM2.5      PM10       SO2       NO2        CO        O3
# PM2.5  1.000000  0.854997  0.474260  0.714036  0.775850 -0.094578
# PM10   0.854997  1.000000  0.453541  0.649564  0.668470 -0.020403
# SO2    0.474260  0.453541  1.000000  0.615631  0.521328 -0.187935
# NO2    0.714036  0.649564  0.615631  1.000000  0.781272 -0.350872
# CO     0.775850  0.668470  0.521328  0.781272  1.000000 -0.291617
# O3    -0.094578 -0.020403 -0.187935 -0.350872 -0.291617  1.000000

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana korelasi antara berbagai polutan (PM2.5, PM10, SO2, NO2, CO, O3)?

# %%
# Menambahkan kolom 'station' untuk menandai lokasi
Aotizhongxin_df["station"] = "Aotizhongxin"
Changping_df["station"] = "Changping"
Dingling_df["station"] = "Dingling"

# Menggabungkan semua dataset
combined_df = pd.concat([Aotizhongxin_df, Changping_df, Dingling_df], ignore_index=True)#

# %%
# Menghitung matriks korelasi untuk setiap lokasi
correlations = {}
stations = combined_df["station"].unique()

for station in stations:
    station_data = combined_df[combined_df["station"] == station]
    correlations[station] = station_data[["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]].corr()

# %%
plt.figure(figsize=(20, 15))  # Mengatur ukuran plot

for i, station in enumerate(stations, 1):
    plt.subplot(2, 2, i)  # Membuat subplot (2x2 grid)
    sn.heatmap(correlations[station], annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
    plt.title(f"Matriks Korelasi - {station}", fontsize=14)

# Menampilkan semua heatmap
plt.tight_layout()
plt.show()

# %% [markdown]
# Nilai mendekati 1 berarti semakin positif hubungan antara polutan, sedangkan korelasi menunjukan nilai mendekati -1 maka jika salah satu variabel naik maka lainnya turun.

# %% [markdown]
# ### Pertanyaan 2: - Apakah ada hubungan antara kecepatan angin (WSPM) dan tingkat polusi udara?

# %%
pollutants = ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]

# Membuat scatter plot untuk setiap polutan
plt.figure(figsize=(15, 10))  # Mengatur ukuran keseluruhan plot
for i, pollutant in enumerate(pollutants, 1):
    plt.subplot(2, 3, i)  # Membuat grid 2x3 untuk setiap polutan
    sn.regplot(
        x="WSPM", 
        y=pollutant, 
        data=Aotizhongxin_df, 
        scatter_kws={"alpha": 0.5},  # Transparansi titik
        line_kws={"color": "red"}  # Warna garis regresi
    )
    plt.title(f"Hubungan WSPM dan {pollutant}", fontsize=12)
    plt.xlabel("Kecepatan Angin (WSPM)", fontsize=10)
    plt.ylabel(f"Konsentrasi {pollutant}", fontsize=10)
    plt.grid(True, linestyle="--", alpha=0.6)

# Menampilkan semua plot
plt.tight_layout()
plt.show()

# %% [markdown]
# didapatkan pola regresi dimana :
#     1. Positif : jika garis miring ke atas, menunjukkan bahwa kecepatan angin cenderung meningkatkan konsentrasi polutan.
#     2. Negatif: Jika garis miring ke bawah, menunjukkan bahwa kecepatan angin cenderung mengurangi konsentrasi polutan.
#     3. Tidak Ada Hubungan: Jika garis mendekati horizontal, menunjukkan tidak ada hubungan linier yang signifikan.

# %% [markdown]
# ### Pertanyaan 3 : Bagaimana kualitas udara pada masing masing stasiun?

# %%
stations = {
    "Aotizhongxin": Aotizhongxin_df,
    "Changping": Changping_df,
    "Dingling": Dingling_df
}

pollutants = ["PM2.5", "PM10", "SO2", "NO2", "CO", "O3"]

# Membuat DataFrame untuk menyimpan rata-rata polutan per stasiun
average_data = pd.DataFrame({
    station_name: station_data[pollutants].mean()
    for station_name, station_data in stations.items()
}).T  # Transpose agar stasiun menjadi indeks

# Membuat bar plot untuk visualisasi rata-rata
plt.figure(figsize=(12, 8))
average_data.plot(kind="bar", figsize=(12, 8), alpha=0.8, colormap="viridis")

# Menambahkan judul dan label
plt.title("Rata-Rata Konsentrasi Polutan di Setiap Stasiun", fontsize=16)
plt.xlabel("Stasiun", fontsize=12)
plt.ylabel("Konsentrasi Polutan (µg/m³)", fontsize=12)
plt.legend(title="Polutan", fontsize=10)
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Menampilkan grafik
plt.tight_layout()
plt.show()

# %% [markdown]
# Visualisasi data dilakukan dengan menganalisis rata rata polutan pada masing masing stasiun

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1
#     Korelasi antara polutan pada masing masing stasiun memiliki kesamaan dimana salah satu polutan naik maka polutan juga ikut naik kecuali untuk polutan O3. Polutan ini tidak memiliki hubungan signifikan dengan kenaikan masing-masing polutan lain.
# - Conclusion pertanyaan 2
#     Pengaruh kecepatan angin (WSPM) dengan berbagai jenis polutan hampir memiliki hubungan yang sama.
#     1. Hubungan Negatif: (Jika kecepatan angin tinggi cenderung menurunkan konsentrasi polutan (misalnya, PM2.5 atau PM10), ini menunjukkan bahwa angin membantu menyebarkan polutan.)
#     2. Hubungan Positif: (Jika kecepatan angin tinggi meningkatkan konsentrasi polutan tertentu (misalnya, O3), ini menunjukkan bahwa angin membawa polutan dari sumber lain.)
# - Conclusion pertanyaan 3
#     Polutan dengan rata rata tertinggi pada masing-masing stasiun adalah CO. sehingga dengan ini bisa analisis apa penyebabanya dan dicari solusinya.

# %%
Aotizhongxin_df["station"] = "Aotizhongxin"
Changping_df["station"] = "Changping"
Dingling_df["station"] = "Dingling"

# Menggabungkan semua DataFrame menjadi satu
all_df = pd.concat([Aotizhongxin_df, Changping_df, Dingling_df], ignore_index=True)

# Menyimpan data gabungan ke file CSV (opsional)
all_df.to_csv("all_data.csv", index=False)

# Menampilkan beberapa baris pertama dari data gabungan
print(all_df.head())
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin
